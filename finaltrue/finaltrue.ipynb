# %%
for i in range(5, 100):
    n = i^10 - 2
    f = n.factor()
    for p, m in list(f):
        if 100 < p< 200 :
            print(i, p)
# Out:
# 5 151
# 7 151
# 18 151
# 29 103
# 29 199
# 32 127
# 40 151
# 43 167
# 52 113
# 56 151
# 58 193
# 61 113
# 74 103
# 95 127
# 95 151

# %%
29^10 % 199
# Out:
# 2

# %%
f = 30.factor()
list(f)
# Out:
# [(2, 1), (3, 1), (5, 1)]

# %%
list(f)[-1][0]
# Out:
# 5
